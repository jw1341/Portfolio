# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('elections.psv', delimiter ='|')
df.replace({'|': ','}, regex=True)
df
# Out:
#       Election ID                        Election Title  Society ID  \
# 0               1     2000 Steering Committee Elections           1
# 1               2                  2001 Board Elections           1
# 2               3         2002 Council Member Elections           1
# 3               4        2003 Executive Board Elections           1
# 4               5             2004 Officer Appointments           1
# ...           ...                                   ...         ...
# 1995         1996         2020 Governing Body Elections          80
# 1996         1997  2021 Committee Chairperson Selection          80
# 1997         1998        2022 Executive Board Elections          80
# 1998         1999               2023 Director Elections          80
# 1999         2000                2024 Trustee Elections          80
#
#       Start Date    End Date
# 0     2000-04-20  2000-05-21
# 1     2001-07-21  2001-09-12
# 2     2002-02-22  2002-04-03
# 3     2003-10-22  2003-12-06
# ...

# %%
df.isnull().sum()
# Out:
# Election ID       0
# Election Title    0
# Society ID        0
# Start Date        0
# End Date          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns = ['election_id', 'election_title', 'society_id', 'start_date', 'end_date']
df
# Out:
#       election_id                        election_title  society_id  \
# 0               1     2000 Steering Committee Elections           1
# 1               2                  2001 Board Elections           1
# 2               3         2002 Council Member Elections           1
# 3               4        2003 Executive Board Elections           1
# 4               5             2004 Officer Appointments           1
# ...           ...                                   ...         ...
# 1995         1996         2020 Governing Body Elections          80
# 1996         1997  2021 Committee Chairperson Selection          80
# 1997         1998        2022 Executive Board Elections          80
# 1998         1999               2023 Director Elections          80
# 1999         2000                2024 Trustee Elections          80
#
#       start_date    end_date
# 0     2000-04-20  2000-05-21
# 1     2001-07-21  2001-09-12
# 2     2002-02-22  2002-04-03
# 3     2003-10-22  2003-12-06
# ...

# %%
df.to_csv('elections.csv', index=False)
