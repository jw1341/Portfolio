# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('societies.txt', delimiter ='|', names=['society_id', 'society_name', 'society_abbr', 'society_field'])
df.replace({'|': ','}, regex=True)
df
# Out:
#     society_id                                       society_name  \
# 0            1                       American Medical Association
# 1            2                 American Psychological Association
# 2            3  Institute of Electrical and Electronics Engineers
# 3            4                          American Chemical Society
# 4            5                           American Bar Association
# ..         ...                                                ...
# 75          76  American Association of Pharmaceutical Scientists
# 76          77              American Association of Immunologists
# 77          78             American Society of Addiction Medicine
# 78          79     American Association of Physicists in Medicine
# 79          80             American Society of Retina Specialists
#
#    society_abbr            society_field
# 0           AMA                 Medicine
# 1           APA               Psychology
# 2          IEEE   Electrical Engineering
# ...

# %%
df.isnull().sum()
# Out:
# society_id       0
# society_name     0
# society_abbr     0
# society_field    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv('societies.csv', index=False)
