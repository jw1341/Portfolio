# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('candidates.psv', delimiter ='|', dtype ={'CandidateId': int, 'MemberID':int, 'SocietyID': int, 'Allowed Votes': int})
df.replace({'|': ','}, regex=True)
df
# Out:
#        Candidate ID  Office ID  Election ID     Office Name  Allowed Votes  \
# 0                 1          1            1       Treasurer              1
# 1                 2          2            1       President              1
# 2                 3          2            1       President              1
# 3                 4          2            1       President              1
# 4                 5          2            1       President              1
# ...             ...        ...          ...             ...            ...
# 12446         12447       4965         1999       President              1
# 12447         12448       4966         2000  Vice President              2
# 12448         12449       4966         2000  Vice President              2
# 12449         12450       4966         2000  Vice President              2
# 12450         12451       4966         2000  Vice President              2
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Candidate ID                 0
# Office ID                    0
# Election ID                  0
# Office Name                  0
# Allowed Votes                0
# Candidate First Name         0
# Candidate Last Name          0
# Candidate Credentials     6228
# Candidate Bio            11204
# dtype: int64

# %%
df.columns = ['candidate_id', 'office_id', 'election_id', 'office_name', 'allowed_votes', 'candidate_first_name', 'candidate_last_name', 'candidate_credentials', 'candidate_bio']
df
# Out:
#        candidate_id  office_id  election_id     office_name  allowed_votes  \
# 0                 1          1            1       Treasurer              1
# 1                 2          2            1       President              1
# 2                 3          2            1       President              1
# 3                 4          2            1       President              1
# 4                 5          2            1       President              1
# ...             ...        ...          ...             ...            ...
# 12446         12447       4965         1999       President              1
# 12447         12448       4966         2000  Vice President              2
# 12448         12449       4966         2000  Vice President              2
# 12449         12450       4966         2000  Vice President              2
# 12450         12451       4966         2000  Vice President              2
#
# ...

# %%
df.to_csv('candidates.csv', index=False)
